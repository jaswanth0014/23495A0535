# %% [markdown]
# <a href="https://colab.research.google.com/github/jaswanth0014/23495A0535/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as rajamouli
movie=['STU NO.1','YAMADONGA','MARYADA RAMANA','EEGA','RRR']
budget=[12,40,30,125,1200]
rajamouli.pie(budget,labels=movie)
ntr=rajamouli.Circle((0,0),0.6,color='white')
rajamouli.gca().add_artist(ntr)
rajamouli.show()

# %%
import pandas as babu
anjali=babu.read_csv('mahesh.csv')
print(anjali)
#print(anjali.head(3))
#print(anjali.tail(2))
ram=anjali['ACTRESS']
#print(ram)
syam=anjali['MOVIE']
#print(syam)
logi=anjali[anjali['ACTRESS']=='Kajal']
#print(logi['MOVIE'])
sai=anjali[anjali['STATUS']=='Blockbuster']
print(len(sai))
gopi=anjali[anjali['GENRE']=='Action']
print(len(gopi))
# Out:
#           MOVIE       STATUS         GENRE            ACTRESS
# 0        Pokiri  Blockbuster        Action     T. Ileana Cruz
# 1        Athadu  Blockbuster        Action             Trisha
# 2   Businessman  Blockbuster  Action-crime              Kajal
# 3   Srimanthudu  Blockbuster  Action-drama      Shruti Haasan
# 4        Spyder          Hit  Spy thriller  Rakul Preet Singh
# 5  Brahmotsavam      Average  Family-drama              Kajal
# 4
# 2

# %%
import pandas as jagan
uppal=jagan.read_csv('jagan.csv')
print(uppal)
#print(uppal['Name'])
#print(uppal[['Name','Target']])
#print(uppal.columns)
#print(uppal.shape)
#print(uppal.info())
#print(uppal.head(5))
#print(uppal.tail(3))
sonu=uppal[uppal['Target']=='Farmers']
#print(sonu['Name'])
abd=uppal[uppal['Name'].str.startswith('j')]
#print(abd)
rcb=uppal[uppal['Target'].str.contains]
# Out:
#                        Name       Date                             Target  \
# 0         YSR Rythu Bharosa  15-Oct-19                            Farmers
# 1                 Amma Vodi  09-Jan-20              Mothers and Guardians
# 2            YSR Aarogyasri  01-Apr-20                       BPL Families
# 3   Jagananna Vidya Deevena  27-Nov-19         Students from BPL Families
# 4        YSR Pension Kanuka  01-Jul-19  Senior Citizens, Disabled, Widows
# 5        YSR Housing Scheme  12-Jul-20                  Homeless Families
# 6      Jagananna Goru Mudda  21-Jan-20                    School Students
# 7              YSR Cheyutha  12-Aug-20     Women from SC/ST/BC/Minorities
# 8                 YSR Asara  11-Sep-20                          SHG Women
# 9          YSR Kapu Nestham  24-Jun-20          Women from Kapu Community
# 10          YSR Law Nestham  05-Dec-19                     Junior Lawyers
# 11          Jagananna Thodu  25-Nov-20                      Small Vendors
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
gopi=pd.read_csv('energy.csv')
print(gopi)
srh=gopi[gopi['State']=="Andhra"]
rcb=gopi[gopi['State']=='Karnataka']
fig1,diag1=plt.subplots(2)
diag1[0].plot(srh['Date'],srh['Consumption'])
diag1[1].plot(rcb['Date'],rcb['Consumption']),color='red'
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]
